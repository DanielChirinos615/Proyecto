# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielChirinos615/Proyecto/blob/main/facto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Contenido Temático
#
# - Recursividad
# - Intro.Listas Enlazadas

# %%
# %%writefile r1.cpp
# #include <iostream>
# int factorial (int n){
#     if(n>1)
#     return n*factorial(n-1);
# }
# int main (){
#     std::cout << factorial(5);
# }
# Out:
# Overwriting r1.cpp

# %%
# !g++ r1.cpp && ./a.out
# Out:
# 120
